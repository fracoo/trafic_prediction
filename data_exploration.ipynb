# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
df = pd.read_csv(
    "dataset/champs_elysees.csv", sep=";", parse_dates=["Date et heure de comptage"]
)
df.head()
# Out:
#    Identifiant arc            Libelle  Date et heure de comptage  \
# 0             4264  AV_Champs_Elysees  2024-12-09 05:00:00+01:00
# 1             4264  AV_Champs_Elysees  2024-12-09 06:00:00+01:00
# 2             4264  AV_Champs_Elysees  2024-12-09 09:00:00+01:00
# 3             4264  AV_Champs_Elysees  2025-09-02 09:00:00+02:00
# 4             4264  AV_Champs_Elysees  2024-09-04 20:00:00+02:00
#
#    Débit horaire  Taux d'occupation Etat trafic  Identifiant noeud amont  \
# 0          199.0            2.20945      Fluide                     2294
# 1          235.0            2.28778      Fluide                     2294
# 2         1041.0           11.63222      Fluide                     2294
# 3         1139.0           28.39222  Pré-saturé                     2294
# 4          686.0           13.21611      Fluide                     2294
#
#             Libelle noeud amont  Identifiant noeud aval  \
# 0  Av_Champs_Elysees-Washington                    2293
# 1  Av_Champs_Elysees-Washington                    2293
# 2  Av_Champs_Elysees-Washington                    2293
# 3  Av_Champs_Elysees-Washington                    2293
# 4  Av_Champs_Elysees-Washington                    2293
#
#         Libelle noeud aval  Etat arc Date debut dispo data  \
# 0  Av_Champs_Elysees-Berri  Invalide            1996-10-10
# 1  Av_Champs_Elysees-Berri  Invalide            1996-10-10
# 2  Av_Champs_Elysees-Berri  Invalide            1996-10-10
# 3  Av_Champs_Elysees-Berri    Ouvert            1996-10-10
# 4  Av_Champs_Elysees-Berri  Invalide            1996-10-10
#
#   Date fin dispo data                           geo_point_2d  \
# 0          2023-01-01  48.87153587897718, 2.3017227924560624
# 1          2023-01-01  48.87153587897718, 2.3017227924560624
# 2          2023-01-01  48.87153587897718, 2.3017227924560624
# 3          2023-01-01  48.87153587897718, 2.3017227924560624
# 4          2023-01-01  48.87153587897718, 2.3017227924560624
#
#                                            geo_shape
# 0  {"coordinates": [[2.3009951475338775, 48.87177...
# 1  {"coordinates": [[2.3009951475338775, 48.87177...
# 2  {"coordinates": [[2.3009951475338775, 48.87177...
# 3  {"coordinates": [[2.3009951475338775, 48.87177...
# 4  {"coordinates": [[2.3009951475338775, 48.87177...

# %%
df.isna().sum()
# Out:
# Identifiant arc                0
# Libelle                        0
# Date et heure de comptage      0
# Débit horaire                563
# Taux d'occupation            622
# Etat trafic                    0
# Identifiant noeud amont        0
# Libelle noeud amont            0
# Identifiant noeud aval         0
# Libelle noeud aval             0
# Etat arc                       0
# Date debut dispo data          0
# Date fin dispo data            0
# geo_point_2d                   0
# geo_shape                      0
# dtype: int64

# %%
fig = go.Figure()
files = [
    "dataset/champs_elysees.csv",
    "dataset/sts_peres.csv",
    "dataset/convention.csv",
]
for file in files:
    tmp = pd.read_csv(file, parse_dates=["Date et heure de comptage"], sep=";")
    tmp = tmp.sort_values(by="Date et heure de comptage")
    fig.add_trace(
        go.Scatter(
            x=tmp["Date et heure de comptage"],
            y=tmp["Débit horaire"],
            mode="lines",
            name=file,
            hovertemplate="%{x}<br>Débit horaire: %{y}<extra></extra>",
        )
    )

fig.update_layout(
    title="Débit horaire vs Date",
    xaxis_title="Date et heure de comptage",
    yaxis_title="Débit horaire",
    legend_title="Fichier",
)
fig.show()

# %% [markdown]
# ## Vacances et jours fériés

# %%
vacances = pd.read_csv(
    "dataset/vacances.csv",
    parse_dates=["Date de début", "Date de fin"],
    sep=";",
    index_col=0,
)

feries = vacances.iloc[18:]
feries["Date de début"] = pd.to_datetime(feries["Date de début"])
feries["Date de fin"] = pd.to_datetime(feries["Date de fin"]) + pd.Timedelta(days=1)


vacances = vacances.iloc[:18]  # keep only metropolitan France
vacances["Date de début"] = pd.to_datetime(vacances["Date de début"], utc=True)
vacances["Date de fin"] = pd.to_datetime(vacances["Date de fin"], utc=True)

vacances.tail()
# Out:
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/31825935.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/31825935.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               Description Population             Date de début  \
# 13    Pont de l'Ascension          - 2024-05-08 22:00:00+00:00
# 14         Vacances d'Été     Élèves 2024-07-05 22:00:00+00:00
# 15    Pont de l'Ascension          - 2025-05-28 22:00:00+00:00
# 16         Vacances d'Été     Élèves 2025-07-04 22:00:00+00:00
# 17  Vacances de Printemps          - 2026-04-17 22:00:00+00:00
#
#                  Date de fin Académies   Zones annee_scolaire
# 13 2024-05-12 22:00:00+00:00     Paris  Zone C      2023-2024
# 14 2024-09-01 22:00:00+00:00     Paris  Zone C      2023-2024
# 15 2025-06-01 22:00:00+00:00     Paris  Zone C      2024-2025
# 16 2025-08-31 22:00:00+00:00     Paris  Zone C      2024-2025
# 17 2026-05-03 22:00:00+00:00     Paris  Zone C      2025-2026

# %%
feries.head()
# Out:
#         Description Population Date de début Date de fin Académies   Zones  \
# 18  All Saints' Day          -    2023-11-01  2023-11-02     Paris  Zone C
# 19    Armistice Day          -    2023-11-11  2023-11-12     Paris  Zone C
# 20    Christmas Day          -    2023-12-25  2023-12-26     Paris  Zone C
# 21   New Year's Day          -    2024-01-01  2024-01-02     Paris  Zone C
# 22    Easter Monday          -    2024-04-01  2024-04-02     Paris  Zone C
#
#    annee_scolaire
# 18      2023-2024
# 19      2023-2024
# 20      2023-2024
# 21      2023-2024
# 22      2023-2024

# %%
def add_off_days_columns(df):
    df["is_holiday"] = (
        df["Date et heure de comptage"]
        .apply(
            lambda x: any(
                (x >= row["Date de début"]) and (x < row["Date de fin"])
                for _, row in vacances.iterrows()
            )
        )
        .astype(int)
    )
    df["is_off_day"] = (
        df["Date et heure de comptage"]
        .apply(
            lambda x: any(
                (x.date() >= row["Date de début"].date())
                and (x.date() < row["Date de fin"].date())
                for _, row in feries.iterrows()
            )
        )
        .astype(int)
    )
    return df


df = add_off_days_columns(df)
df.head()
# Out:
#    Identifiant arc            Libelle  Date et heure de comptage  \
# 0             4264  AV_Champs_Elysees  2024-12-09 05:00:00+01:00
# 1             4264  AV_Champs_Elysees  2024-12-09 06:00:00+01:00
# 2             4264  AV_Champs_Elysees  2024-12-09 09:00:00+01:00
# 3             4264  AV_Champs_Elysees  2025-09-02 09:00:00+02:00
# 4             4264  AV_Champs_Elysees  2024-09-04 20:00:00+02:00
#
#    Débit horaire  Taux d'occupation Etat trafic  Identifiant noeud amont  \
# 0          199.0            2.20945      Fluide                     2294
# 1          235.0            2.28778      Fluide                     2294
# 2         1041.0           11.63222      Fluide                     2294
# 3         1139.0           28.39222  Pré-saturé                     2294
# 4          686.0           13.21611      Fluide                     2294
#
#             Libelle noeud amont  Identifiant noeud aval  \
# 0  Av_Champs_Elysees-Washington                    2293
# 1  Av_Champs_Elysees-Washington                    2293
# 2  Av_Champs_Elysees-Washington                    2293
# 3  Av_Champs_Elysees-Washington                    2293
# 4  Av_Champs_Elysees-Washington                    2293
#
#         Libelle noeud aval  Etat arc Date debut dispo data  \
# 0  Av_Champs_Elysees-Berri  Invalide            1996-10-10
# 1  Av_Champs_Elysees-Berri  Invalide            1996-10-10
# 2  Av_Champs_Elysees-Berri  Invalide            1996-10-10
# 3  Av_Champs_Elysees-Berri    Ouvert            1996-10-10
# 4  Av_Champs_Elysees-Berri  Invalide            1996-10-10
#
#   Date fin dispo data                           geo_point_2d  \
# 0          2023-01-01  48.87153587897718, 2.3017227924560624
# 1          2023-01-01  48.87153587897718, 2.3017227924560624
# 2          2023-01-01  48.87153587897718, 2.3017227924560624
# 3          2023-01-01  48.87153587897718, 2.3017227924560624
# 4          2023-01-01  48.87153587897718, 2.3017227924560624
#
#                                            geo_shape  is_holiday  is_off_day
# 0  {"coordinates": [[2.3009951475338775, 48.87177...           0           0
# 1  {"coordinates": [[2.3009951475338775, 48.87177...           0           0
# 2  {"coordinates": [[2.3009951475338775, 48.87177...           0           0
# 3  {"coordinates": [[2.3009951475338775, 48.87177...           0           0
# 4  {"coordinates": [[2.3009951475338775, 48.87177...           0           0

# %% [markdown]
# ## Paris Respire

# %%
paris_respire = pd.read_csv("dataset/paris_respire.csv", parse_dates=["date"], sep=",")[
    ["date"]
]
paris_respire["date"] = pd.to_datetime(paris_respire["date"])
paris_respire.head()
# Out:
#         date
# 0 2024-09-08
# 1 2024-10-06
# 2 2024-11-24
# 3 2024-12-01
# 4 2025-01-05

# %%
def add_paris_respire_column(df, paris_respire):
    df["is_paris_respire"] = df["Date et heure de comptage"].apply(
        lambda x: int(
            x.date() in pd.to_datetime(paris_respire["date"]).dt.date.values
            and 10 <= x.hour <= 18
        )
    )
    return df


df = add_paris_respire_column(df, paris_respire)
df[
    df["Date et heure de comptage"].apply(lambda x: x.date())
    == pd.to_datetime("2025-09-21").date()
].head()
# Out:
#       Identifiant arc            Libelle  Date et heure de comptage  \
# 6532             4264  AV_Champs_Elysees  2025-09-21 22:00:00+02:00
# 6533             4264  AV_Champs_Elysees  2025-09-21 21:00:00+02:00
# 6534             4264  AV_Champs_Elysees  2025-09-21 20:00:00+02:00
# 6535             4264  AV_Champs_Elysees  2025-09-21 19:00:00+02:00
# 6536             4264  AV_Champs_Elysees  2025-09-21 17:00:00+02:00
#
#       Débit horaire  Taux d'occupation Etat trafic  Identifiant noeud amont  \
# 6532          227.0           10.61222      Fluide                     2294
# 6533          270.0           11.26500      Fluide                     2294
# 6534          271.0           16.32556  Pré-saturé                     2294
# 6535          301.0           13.91778      Fluide                     2294
# 6536          323.0           16.30389  Pré-saturé                     2294
#
#                Libelle noeud amont  Identifiant noeud aval  \
# 6532  Av_Champs_Elysees-Washington                    2293
# 6533  Av_Champs_Elysees-Washington                    2293
# 6534  Av_Champs_Elysees-Washington                    2293
# 6535  Av_Champs_Elysees-Washington                    2293
# 6536  Av_Champs_Elysees-Washington                    2293
#
#            Libelle noeud aval Etat arc Date debut dispo data  \
# 6532  Av_Champs_Elysees-Berri   Ouvert            1996-10-10
# 6533  Av_Champs_Elysees-Berri   Ouvert            1996-10-10
# 6534  Av_Champs_Elysees-Berri   Ouvert            1996-10-10
# 6535  Av_Champs_Elysees-Berri   Ouvert            1996-10-10
# 6536  Av_Champs_Elysees-Berri   Ouvert            1996-10-10
#
#      Date fin dispo data                           geo_point_2d  \
# 6532          2023-01-01  48.87153587897718, 2.3017227924560624
# 6533          2023-01-01  48.87153587897718, 2.3017227924560624
# 6534          2023-01-01  48.87153587897718, 2.3017227924560624
# 6535          2023-01-01  48.87153587897718, 2.3017227924560624
# 6536          2023-01-01  48.87153587897718, 2.3017227924560624
#
#                                               geo_shape  is_holiday  \
# 6532  {"coordinates": [[2.3009951475338775, 48.87177...           0
# 6533  {"coordinates": [[2.3009951475338775, 48.87177...           0
# 6534  {"coordinates": [[2.3009951475338775, 48.87177...           0
# 6535  {"coordinates": [[2.3009951475338775, 48.87177...           0
# 6536  {"coordinates": [[2.3009951475338775, 48.87177...           0
#
#       is_off_day  is_paris_respire
# 6532           0                 0
# 6533           0                 0
# 6534           0                 0
# 6535           0                 0
# 6536           0                 1

# %% [markdown]
# ## XGBoost Model

# %%
fig = go.Figure()
file = "dataset/champs_elysees.csv"
df = pd.read_csv(file, parse_dates=["Date et heure de comptage"], sep=";")
df = add_off_days_columns(df)
df = add_paris_respire_column(df, paris_respire)
df = df.sort_values(by="Date et heure de comptage")
# plot full series in blue
fig.add_trace(
    go.Scatter(
        x=df["Date et heure de comptage"],
        y=df["Débit horaire"],
        mode="lines",
        name=file,
        line=dict(color="blue"),
        hovertemplate="%{x}<br>Débit horaire: %{y}<extra></extra>",
    )
)

# overlay holiday points in red
holidays = df[df["is_holiday"] == 1]
fig.add_trace(
    go.Scatter(
        x=holidays["Date et heure de comptage"],
        y=holidays["Débit horaire"],
        mode="markers",
        name=f"{file} - holiday",
        marker=dict(color="red", size=6),
        hovertemplate="%{x}<br>Débit horaire: %{y}<extra></extra>",
    )
)
off_days = df[df["is_off_day"] == 1]
fig.add_trace(
    go.Scatter(
        x=off_days["Date et heure de comptage"],
        y=off_days["Débit horaire"],
        mode="markers",
        name=f"{file} - off day",
        marker=dict(color="purple", size=6),
        hovertemplate="%{x}<br>Débit horaire: %{y}<extra></extra>",
    )
)
paris_respire_days = df[df["is_paris_respire"] == 1]
fig.add_trace(
    go.Scatter(
        x=paris_respire_days["Date et heure de comptage"],
        y=paris_respire_days["Débit horaire"],
        mode="markers",
        name=f"{file} - Paris Respire",
        marker=dict(color="green", size=6),
        hovertemplate="%{x}<br>Débit horaire: %{y}<extra></extra>",
    )
)

# %%
df.head()
# Out:
#       Identifiant arc            Libelle  Date et heure de comptage  \
# 2472             4264  AV_Champs_Elysees  2024-09-01 05:00:00+02:00
# 2437             4264  AV_Champs_Elysees  2024-09-01 06:00:00+02:00
# 2471             4264  AV_Champs_Elysees  2024-09-01 07:00:00+02:00
# 2470             4264  AV_Champs_Elysees  2024-09-01 08:00:00+02:00
# 2469             4264  AV_Champs_Elysees  2024-09-01 09:00:00+02:00
#
#       Débit horaire  Taux d'occupation Etat trafic  Identifiant noeud amont  \
# 2472          532.0            8.08889      Fluide                     2294
# 2437          331.0            3.91500      Fluide                     2294
# 2471          272.0            2.69167      Fluide                     2294
# 2470          191.0            2.23612      Fluide                     2294
# 2469          201.0            2.63333      Fluide                     2294
#
#                Libelle noeud amont  Identifiant noeud aval  \
# 2472  Av_Champs_Elysees-Washington                    2293
# 2437  Av_Champs_Elysees-Washington                    2293
# 2471  Av_Champs_Elysees-Washington                    2293
# 2470  Av_Champs_Elysees-Washington                    2293
# 2469  Av_Champs_Elysees-Washington                    2293
#
#            Libelle noeud aval  Etat arc Date debut dispo data  \
# 2472  Av_Champs_Elysees-Berri  Invalide            1996-10-10
# 2437  Av_Champs_Elysees-Berri  Invalide            1996-10-10
# 2471  Av_Champs_Elysees-Berri  Invalide            1996-10-10
# 2470  Av_Champs_Elysees-Berri  Invalide            1996-10-10
# 2469  Av_Champs_Elysees-Berri  Invalide            1996-10-10
#
#      Date fin dispo data                           geo_point_2d  \
# 2472          2023-01-01  48.87153587897718, 2.3017227924560624
# 2437          2023-01-01  48.87153587897718, 2.3017227924560624
# 2471          2023-01-01  48.87153587897718, 2.3017227924560624
# 2470          2023-01-01  48.87153587897718, 2.3017227924560624
# 2469          2023-01-01  48.87153587897718, 2.3017227924560624
#
#                                               geo_shape  is_holiday  \
# 2472  {"coordinates": [[2.3009951475338775, 48.87177...           1
# 2437  {"coordinates": [[2.3009951475338775, 48.87177...           1
# 2471  {"coordinates": [[2.3009951475338775, 48.87177...           1
# 2470  {"coordinates": [[2.3009951475338775, 48.87177...           1
# 2469  {"coordinates": [[2.3009951475338775, 48.87177...           1
#
#       is_off_day  is_paris_respire
# 2472           0                 0
# 2437           0                 0
# 2471           0                 0
# 2470           0                 0
# 2469           0                 0

# %%
N_day_lags = 10


def process_lags(df, N_day_lags):
    df["Date et heure de comptage"] = pd.to_datetime(
        df["Date et heure de comptage"], utc=True
    )
    df = df.sort_values("Date et heure de comptage").set_index(
        "Date et heure de comptage"
    )

    # 1️⃣ Reconstituer toutes les heures manquantes
    full_index = pd.date_range(df.index.min(), df.index.max(), freq="H")
    df = df.reindex(full_index)

    # 2️⃣ Créer les lags
    Lags = []
    for lag_day in range(1, N_day_lags + 1):
        for lag_hour in range(24):
            lag_name = f"lag_{lag_day}_{lag_hour}"
            df[lag_name] = df["Débit horaire"].shift(lag_day * 24 + lag_hour)
            Lags.append(lag_name)

    # 3️⃣ Remettre les dates initiales (optionnel)
    df = df.reset_index().rename(columns={"index": "Date et heure de comptage"})
    return df, Lags


df, Lags = process_lags(df, N_day_lags)
# Out:
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:13: FutureWarning:
#
# 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/xg/rvzw_pbd30q5v8_mjx4dks4h0000gn/T/ipykernel_96155/1217835719.py:21: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`

# %%
df[Lags].head()
# Out:
#    lag_1_0  lag_1_1  lag_1_2  lag_1_3  lag_1_4  lag_1_5  lag_1_6  lag_1_7  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    lag_1_8  lag_1_9  ...  lag_10_14  lag_10_15  lag_10_16  lag_10_17  \
# 0      NaN      NaN  ...        NaN        NaN        NaN        NaN
# 1      NaN      NaN  ...        NaN        NaN        NaN        NaN
# 2      NaN      NaN  ...        NaN        NaN        NaN        NaN
# 3      NaN      NaN  ...        NaN        NaN        NaN        NaN
# 4      NaN      NaN  ...        NaN        NaN        NaN        NaN
#
#    lag_10_18  lag_10_19  lag_10_20  lag_10_21  lag_10_22  lag_10_23
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
# [5 rows x 240 columns]

# %%
from xgboost import XGBRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
import joblib


# prepare data
df_ml = df.copy()
df_ml["Date et heure de comptage"] = pd.to_datetime(
    df_ml["Date et heure de comptage"], utc=True
)
print(df_ml["Date et heure de comptage"].isna().sum())
df_ml = df_ml.reset_index(drop=True).sort_values(by="Date et heure de comptage")

# handle missing target
df_ml = df_ml[~df_ml["Débit horaire"].isna()]

# feature engineering: temporal features + existing numeric/categorical
df_ml["cos_hour"] = np.cos(df_ml["Date et heure de comptage"].dt.hour / 24 * 2 * np.pi)
df_ml["cos_dayofweek"] = np.cos(
    df_ml["Date et heure de comptage"].dt.dayofweek / 7 * 2 * np.pi
)
df_ml["cos_month"] = np.cos(
    df_ml["Date et heure de comptage"].dt.month / 12 * 2 * np.pi
)
df_ml["sin_hour"] = np.sin(df_ml["Date et heure de comptage"].dt.hour / 24 * 2 * np.pi)
df_ml["sin_dayofweek"] = np.sin(
    df_ml["Date et heure de comptage"].dt.dayofweek / 7 * 2 * np.pi
)
df_ml["sin_month"] = np.sin(
    df_ml["Date et heure de comptage"].dt.month / 12 * 2 * np.pi
)

# select features
feat_num = [
    "cos_hour",
    "cos_dayofweek",
    "cos_month",
    "sin_hour",
    "sin_dayofweek",
    "sin_month",
    "is_holiday",
    "is_off_day",
]
feat_cat = []  # label-encode these categorical cols
features = feat_num + feat_cat + Lags

# fill/encode
# df_ml["Taux d'occupation"] = df_ml["Taux d'occupation"].fillna(
#     df_ml["Taux d'occupation"].median()
# )
for c in feat_cat:
    df_ml[c] = df_ml[c].fillna("NA")
    le = LabelEncoder()
    df_ml[c] = le.fit_transform(df_ml[c].astype(str))

X = df_ml[features]
y = df_ml["Débit horaire"]

# train/valid split (80/20)
N_train = int(0.8 * len(df_ml))
X_train = X[:N_train]
y_train = y[:N_train]
X_valid = X[N_train:]
y_valid = y[N_train:]

print(f"Training samples: {len(X_train)}, features: {X_train.shape[1]}")
# XGBoost regressor (sklearn API)
model = XGBRegressor(
    n_estimators=500,
    max_depth=20,
    learning_rate=0.05,
    objective="reg:squarederror",
    random_state=42,
    n_jobs=-1,
    colsample_bytree=0.1,
    rowsample=0.5,
)

# set eval metric on the model (don't pass eval_metric to fit)
model.set_params(eval_metric="rmse")
model.fit(
    X_train,
    y_train,
    eval_set=[(X_train, y_train), (X_valid, y_valid)],
    verbose=True,
)

# evaluation
preds = model.predict(X_valid)
rmse = np.sqrt(mean_squared_error(y_valid, preds))
print(f"Validation RMSE: {rmse:.2f}")

# save model
joblib.dump(model, "xgb_debit_horaire.joblib")
# Out:
# 0
# Training samples: 6962, features: 248
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning:
#
# [22:28:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "rowsample" } are not used.
# [0]	validation_0-rmse:291.81352	validation_1-rmse:244.64837
# [1]	validation_0-rmse:279.12937	validation_1-rmse:236.46452
# [2]	validation_0-rmse:267.12964	validation_1-rmse:228.99504
# [3]	validation_0-rmse:255.74742	validation_1-rmse:221.97569
# [4]	validation_0-rmse:244.63923	validation_1-rmse:215.14649
# [5]	validation_0-rmse:234.14177	validation_1-rmse:208.33836
# [6]	validation_0-rmse:224.10234	validation_1-rmse:202.51242
# [7]	validation_0-rmse:214.74167	validation_1-rmse:196.84113
# [8]	validation_0-rmse:205.56107	validation_1-rmse:191.31559
# [9]	validation_0-rmse:196.85685	validation_1-rmse:186.90450
# [10]	validation_0-rmse:188.43870	validation_1-rmse:182.53421
# [11]	validation_0-rmse:180.71292	validation_1-rmse:178.28118
# [12]	validation_0-rmse:173.11823	validation_1-rmse:174.29171
# [13]	validation_0-rmse:165.84347	validation_1-rmse:170.59926
# [14]	validation_0-rmse:159.00089	validation_1-rmse:167.44300
# [15]	validation_0-rmse:152.32222	validation_1-rmse:164.11182
# [16]	validation_0-rmse:146.02148	validation_1-rmse:161.00572
# [157]	validation_0-rmse:10.03814	validation_1-rmse:124.26816
# [158]	validation_0-rmse:10.03371	validation_1-rmse:124.26759
# [159]	validation_0-rmse:9.89596	validation_1-rmse:124.26643
# [160]	validation_0-rmse:9.88798	validation_1-rmse:124.26347
# [161]	validation_0-rmse:9.88272	validation_1-rmse:124.26236
# [162]	validation_0-rmse:9.87216	validation_1-rmse:124.25885
# [163]	validation_0-rmse:9.86885	validation_1-rmse:124.25703
# [164]	validation_0-rmse:9.86406	validation_1-rmse:124.25699
# [165]	validation_0-rmse:9.65257	validation_1-rmse:124.25430
# [166]	validation_0-rmse:9.64905	validation_1-rmse:124.25340
# [167]	validation_0-rmse:9.64632	validation_1-rmse:124.25307
# [168]	validation_0-rmse:9.63265	validation_1-rmse:124.25242
# [169]	validation_0-rmse:9.61898	validation_1-rmse:124.25150
# [170]	validation_0-rmse:9.60719	validation_1-rmse:124.24988
# [171]	validation_0-rmse:9.60424	validation_1-rmse:124.24882
# [172]	validation_0-rmse:9.59983	validation_1-rmse:124.24816
# [173]	validation_0-rmse:9.59536	validation_1-rmse:124.24743
# [174]	validation_0-rmse:9.59108	validation_1-rmse:124.24372
# [175]	validation_0-rmse:9.58887	validation_1-rmse:124.24480
# [176]	validation_0-rmse:9.58594	validation_1-rmse:124.24464
# [177]	validation_0-rmse:9.57703	validation_1-rmse:124.24480
# [178]	validation_0-rmse:9.56980	validation_1-rmse:124.24316
# [179]	validation_0-rmse:9.52145	validation_1-rmse:124.24255
# [180]	validation_0-rmse:9.52001	validation_1-rmse:124.24212
# [181]	validation_0-rmse:9.51766	validation_1-rmse:124.24087
# [182]	validation_0-rmse:9.51436	validation_1-rmse:124.24024
# [183]	validation_0-rmse:9.51278	validation_1-rmse:124.23965
# [184]	validation_0-rmse:9.30512	validation_1-rmse:124.23937
# [185]	validation_0-rmse:9.30081	validation_1-rmse:124.23900
# [186]	validation_0-rmse:9.29699	validation_1-rmse:124.23922
# [187]	validation_0-rmse:9.29610	validation_1-rmse:124.23930
# [188]	validation_0-rmse:9.29111	validation_1-rmse:124.23705
# [189]	validation_0-rmse:9.28731	validation_1-rmse:124.23706
# [190]	validation_0-rmse:9.19454	validation_1-rmse:124.23688
# [191]	validation_0-rmse:9.18952	validation_1-rmse:124.23682
# [192]	validation_0-rmse:9.18732	validation_1-rmse:124.23652
# [193]	validation_0-rmse:9.18422	validation_1-rmse:124.23600
# [194]	validation_0-rmse:9.17978	validation_1-rmse:124.23604
# [195]	validation_0-rmse:9.14830	validation_1-rmse:124.23561
# [196]	validation_0-rmse:9.14681	validation_1-rmse:124.23568
# [197]	validation_0-rmse:9.14493	validation_1-rmse:124.23536
# [198]	validation_0-rmse:8.99754	validation_1-rmse:124.23653
# [199]	validation_0-rmse:8.99172	validation_1-rmse:124.23633
# [200]	validation_0-rmse:8.99111	validation_1-rmse:124.23652
# [201]	validation_0-rmse:8.83790	validation_1-rmse:124.23605
# [202]	validation_0-rmse:8.83587	validation_1-rmse:124.23612
# [203]	validation_0-rmse:8.83520	validation_1-rmse:124.23595
# [204]	validation_0-rmse:8.71938	validation_1-rmse:124.23641
# [205]	validation_0-rmse:8.71802	validation_1-rmse:124.23564
# [206]	validation_0-rmse:8.71705	validation_1-rmse:124.23585
# [207]	validation_0-rmse:8.71559	validation_1-rmse:124.23715
# [208]	validation_0-rmse:8.71485	validation_1-rmse:124.23700
# [209]	validation_0-rmse:8.63798	validation_1-rmse:124.23684
# [210]	validation_0-rmse:8.63700	validation_1-rmse:124.23645
# [211]	validation_0-rmse:8.54927	validation_1-rmse:124.23647
# [212]	validation_0-rmse:8.52236	validation_1-rmse:124.23638
# [213]	validation_0-rmse:8.52160	validation_1-rmse:124.23674
# [214]	validation_0-rmse:8.51765	validation_1-rmse:124.23650
# [215]	validation_0-rmse:8.51615	validation_1-rmse:124.23616
# [216]	validation_0-rmse:8.51548	validation_1-rmse:124.23621
# [217]	validation_0-rmse:8.51454	validation_1-rmse:124.23612
# [218]	validation_0-rmse:8.51293	validation_1-rmse:124.23585
# [219]	validation_0-rmse:8.51233	validation_1-rmse:124.23592
# [220]	validation_0-rmse:8.48884	validation_1-rmse:124.23658
# [221]	validation_0-rmse:8.48771	validation_1-rmse:124.23663
# [222]	validation_0-rmse:8.41181	validation_1-rmse:124.23604
# [223]	validation_0-rmse:8.40986	validation_1-rmse:124.23607
# [224]	validation_0-rmse:8.40854	validation_1-rmse:124.23592
# [225]	validation_0-rmse:8.40551	validation_1-rmse:124.23591
# [226]	validation_0-rmse:8.37238	validation_1-rmse:124.23596
# [227]	validation_0-rmse:8.37093	validation_1-rmse:124.23589
# [228]	validation_0-rmse:8.36994	validation_1-rmse:124.23550
# [229]	validation_0-rmse:8.36791	validation_1-rmse:124.23551
# [230]	validation_0-rmse:8.29871	validation_1-rmse:124.23540
# [231]	validation_0-rmse:8.29828	validation_1-rmse:124.23516
# [232]	validation_0-rmse:8.29674	validation_1-rmse:124.23513
# [233]	validation_0-rmse:8.28960	validation_1-rmse:124.23491
# [234]	validation_0-rmse:8.19186	validation_1-rmse:124.23479
# [235]	validation_0-rmse:8.19099	validation_1-rmse:124.23479
# [236]	validation_0-rmse:8.12147	validation_1-rmse:124.23473
# [237]	validation_0-rmse:8.12053	validation_1-rmse:124.23478
# [238]	validation_0-rmse:8.11852	validation_1-rmse:124.23489
# [239]	validation_0-rmse:8.11840	validation_1-rmse:124.23497
# [240]	validation_0-rmse:8.11807	validation_1-rmse:124.23495
# [241]	validation_0-rmse:8.11549	validation_1-rmse:124.23480
# [242]	validation_0-rmse:8.05477	validation_1-rmse:124.23523
# [243]	validation_0-rmse:8.05426	validation_1-rmse:124.23531
# [244]	validation_0-rmse:8.05291	validation_1-rmse:124.23522
# [245]	validation_0-rmse:7.88749	validation_1-rmse:124.23452
# [246]	validation_0-rmse:7.81135	validation_1-rmse:124.23464
# [247]	validation_0-rmse:7.80989	validation_1-rmse:124.23404
# [248]	validation_0-rmse:7.79111	validation_1-rmse:124.23362
# [249]	validation_0-rmse:7.73758	validation_1-rmse:124.23348
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 82
#      80 # set eval metric on the model (don't pass eval_metric to fit)
#      81 model.set_params(eval_metric="rmse")
# ---> 82 model.fit(
#      83     X_train,
#      84     y_train,
#      85     eval_set=[(X_train, y_train), (X_valid, y_valid)],
#      86     verbose=True,
#      87 )
#      89 # evaluation
#      90 preds = model.predict(X_valid)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/sklearn.py:1247, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1244 else:
#    1245     obj = None
# -> 1247 self._Booster = train(
#    1248     params,
#    1249     train_dmatrix,
#    1250     self.get_num_boosting_rounds(),
#    1251     evals=evals,
#    1252     early_stopping_rounds=self.early_stopping_rounds,
#    1253     evals_result=evals_result,
#    1254     obj=obj,
#    1255     custom_metric=metric,
#    1256     verbose_eval=verbose,
#    1257     xgb_model=model,
#    1258     callbacks=self.callbacks,
#    1259 )
#    1261 self._set_evaluation_result(evals_result)
#    1262 return self
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     181 if cb_container.before_iteration(bst, i, dtrain, evals):
#     182     break
# --> 183 bst.update(dtrain, iteration=i, fobj=obj)
#     184 if cb_container.after_iteration(bst, i, dtrain, evals):
#     185     break
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/core.py:2247, in Booster.update(self, dtrain, iteration, fobj)
#    2243 self._assign_dmatrix_features(dtrain)
#    2245 if fobj is None:
#    2246     _check_call(
# -> 2247         _LIB.XGBoosterUpdateOneIter(
#    2248             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2249         )
#    2250     )
#    2251 else:
#    2252     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
print(X_train.shape, y_train.shape, X_valid.shape, y_valid.shape, X.shape, y.shape)
# Out:
# (6962, 248) (6962,) (1741, 248) (1741,) (8703, 248) (8703,)

# %%
X_train
# Out:
#           cos_hour  cos_dayofweek     cos_month  sin_hour  sin_dayofweek  \
# 0     7.071068e-01       0.623490 -1.836970e-16  0.707107      -0.781831
# 1     5.000000e-01       0.623490 -1.836970e-16  0.866025      -0.781831
# 2     2.588190e-01       0.623490 -1.836970e-16  0.965926      -0.781831
# 3     6.123234e-17       0.623490 -1.836970e-16  1.000000      -0.781831
# 4    -2.588190e-01       0.623490 -1.836970e-16  0.965926      -0.781831
# ...            ...            ...           ...       ...            ...
# 8346  7.071068e-01      -0.900969 -5.000000e-01 -0.707107       0.433884
# 8347  8.660254e-01      -0.900969 -5.000000e-01 -0.500000       0.433884
# 8348  9.659258e-01      -0.900969 -5.000000e-01 -0.258819       0.433884
# 8349  1.000000e+00      -0.900969 -5.000000e-01  0.000000      -0.433884
# 8352  7.071068e-01      -0.900969 -5.000000e-01  0.707107      -0.433884
#
#       sin_month  is_holiday  is_off_day  lag_1_0  lag_1_1  ...  lag_10_14  \
# 0     -1.000000         1.0         0.0      NaN      NaN  ...        NaN
# 1     -1.000000         1.0         0.0      NaN      NaN  ...        NaN
# 2     -1.000000         1.0         0.0      NaN      NaN  ...        NaN
# 3     -1.000000         1.0         0.0      NaN      NaN  ...        NaN
# 4     -1.000000         1.0         0.0      NaN      NaN  ...        NaN
# ...         ...         ...         ...      ...      ...  ...        ...
# 8346  -0.866025         1.0         0.0    660.0    649.0  ...      868.0
# 8347  -0.866025         1.0         1.0    608.0    660.0  ...      751.0
# 8348  -0.866025         1.0         1.0    560.0    608.0  ...      844.0
# 8349  -0.866025         1.0         1.0    434.0    560.0  ...      882.0
# 8352  -0.866025         1.0         1.0    157.0    212.0  ...      946.0
#
#       lag_10_15  lag_10_16  lag_10_17  lag_10_18  lag_10_19  lag_10_20  \
# 0           NaN        NaN        NaN        NaN        NaN        NaN
# 1           NaN        NaN        NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN        NaN        NaN
# 3           NaN        NaN        NaN        NaN        NaN        NaN
# 4           NaN        NaN        NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...        ...        ...
# 8346      602.0      361.0      225.0      150.0      207.0      390.0
# 8347      868.0      602.0      361.0      225.0      150.0      207.0
# 8348      751.0      868.0      602.0      361.0      225.0      150.0
# 8349      844.0      751.0      868.0      602.0      361.0      225.0
# 8352      919.0      890.0      882.0      844.0      751.0      868.0
#
#       lag_10_21  lag_10_22  lag_10_23
# 0           NaN        NaN        NaN
# 1           NaN        NaN        NaN
# 2           NaN        NaN        NaN
# 3           NaN        NaN        NaN
# 4           NaN        NaN        NaN
# ...         ...        ...        ...
# 8346      498.0      591.0      626.0
# 8347      390.0      498.0      591.0
# 8348      207.0      390.0      498.0
# 8349      150.0      207.0      390.0
# 8352      602.0      361.0      225.0
#
# [6962 rows x 248 columns]

# %%
# combine predictions with validation ground truth and timestamps, then plot
pred_series_val = pd.Series(preds, index=X_valid.index, name="pred")
pred_series_train = pd.Series(model.predict(X_train), index=X_train.index, name="pred")

plot_df_val = (
    pd.DataFrame(
        {
            "date": df_ml.loc[X_valid.index, "Date et heure de comptage"],
            "actual": y_valid,
            "pred": pred_series_val,
        }
    )
    .sort_values("date")
    .reset_index(drop=True)
)
plot_df_train = (
    pd.DataFrame(
        {
            "date": df_ml.loc[X_train.index, "Date et heure de comptage"],
            "actual": y_train,
            "pred": pred_series_train,
        }
    )
    .sort_values("date")
    .reset_index(drop=True)
)

fig_pred = go.Figure()
fig_pred.add_trace(
    go.Scatter(
        x=plot_df_val["date"],
        y=plot_df_val["actual"],
        mode="lines+markers",
        name="VAL - Actual Débit horaire",
        line=dict(color="blue"),
        hovertemplate="%{x}<br>Actual: %{y}<extra></extra>",
    )
)
fig_pred.add_trace(
    go.Scatter(
        x=plot_df_val["date"],
        y=plot_df_val["pred"],
        mode="lines+markers",
        name="VAL - Predicted Débit horaire",
        line=dict(color="red"),
        hovertemplate="%{x}<br>Predicted: %{y:.1f}<extra></extra>",
    )
)
fig_pred.add_trace(
    go.Scatter(
        x=plot_df_train["date"],
        y=plot_df_train["actual"],
        mode="lines+markers",
        name="TRAIN - Actual Débit horaire",
        line=dict(color="lightblue"),
        hovertemplate="%{x}<br>Actual: %{y}<extra></extra>",
    )
)
fig_pred.add_trace(
    go.Scatter(
        x=plot_df_train["date"],
        y=plot_df_train["pred"],
        mode="lines+markers",
        name="TRAIN - Predicted Débit horaire",
        line=dict(color="lightcoral"),
        hovertemplate="%{x}<br>Predicted: %{y:.1f}<extra></extra>",
    )
)

fig_pred.update_layout(
    title="Actual vs Predicted Débit horaire (validation set) over time",
    xaxis_title="Date et heure de comptage",
    yaxis_title="Débit horaire",
    legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1),
)
fig_pred.show()

# %%
df_ml.head()
# Out:
#   Date et heure de comptage  Identifiant arc            Libelle  \
# 0 2024-09-01 03:00:00+00:00           4264.0  AV_Champs_Elysees
# 1 2024-09-01 04:00:00+00:00           4264.0  AV_Champs_Elysees
# 2 2024-09-01 05:00:00+00:00           4264.0  AV_Champs_Elysees
# 3 2024-09-01 06:00:00+00:00           4264.0  AV_Champs_Elysees
# 4 2024-09-01 07:00:00+00:00           4264.0  AV_Champs_Elysees
#
#    Débit horaire  Taux d'occupation Etat trafic  Identifiant noeud amont  \
# 0          532.0            8.08889      Fluide                   2294.0
# 1          331.0            3.91500      Fluide                   2294.0
# 2          272.0            2.69167      Fluide                   2294.0
# 3          191.0            2.23612      Fluide                   2294.0
# 4          201.0            2.63333      Fluide                   2294.0
#
#             Libelle noeud amont  Identifiant noeud aval  \
# 0  Av_Champs_Elysees-Washington                  2293.0
# 1  Av_Champs_Elysees-Washington                  2293.0
# 2  Av_Champs_Elysees-Washington                  2293.0
# 3  Av_Champs_Elysees-Washington                  2293.0
# 4  Av_Champs_Elysees-Washington                  2293.0
#
#         Libelle noeud aval  ... lag_10_20 lag_10_21 lag_10_22 lag_10_23  \
# 0  Av_Champs_Elysees-Berri  ...       NaN       NaN       NaN       NaN
# 1  Av_Champs_Elysees-Berri  ...       NaN       NaN       NaN       NaN
# 2  Av_Champs_Elysees-Berri  ...       NaN       NaN       NaN       NaN
# 3  Av_Champs_Elysees-Berri  ...       NaN       NaN       NaN       NaN
# 4  Av_Champs_Elysees-Berri  ...       NaN       NaN       NaN       NaN
#
#        cos_hour  cos_dayofweek     cos_month  sin_hour  sin_dayofweek  \
# 0  7.071068e-01        0.62349 -1.836970e-16  0.707107      -0.781831
# 1  5.000000e-01        0.62349 -1.836970e-16  0.866025      -0.781831
# 2  2.588190e-01        0.62349 -1.836970e-16  0.965926      -0.781831
# 3  6.123234e-17        0.62349 -1.836970e-16  1.000000      -0.781831
# 4 -2.588190e-01        0.62349 -1.836970e-16  0.965926      -0.781831
#
#    sin_month
# 0       -1.0
# 1       -1.0
# 2       -1.0
# 3       -1.0
# 4       -1.0
#
# [5 rows x 264 columns]

# %%
df_ml.tail()
# Out:
#       Date et heure de comptage  Identifiant arc            Libelle  \
# 10168 2025-10-29 19:00:00+00:00           4264.0  AV_Champs_Elysees
# 10169 2025-10-29 20:00:00+00:00           4264.0  AV_Champs_Elysees
# 10170 2025-10-29 21:00:00+00:00           4264.0  AV_Champs_Elysees
# 10171 2025-10-29 22:00:00+00:00           4264.0  AV_Champs_Elysees
# 10172 2025-10-29 23:00:00+00:00           4264.0  AV_Champs_Elysees
#
#        Débit horaire  Taux d'occupation Etat trafic  Identifiant noeud amont  \
# 10168          998.0           19.26056  Pré-saturé                   2294.0
# 10169         1041.0           20.32667  Pré-saturé                   2294.0
# 10170          658.0           11.17000      Fluide                   2294.0
# 10171          650.0           14.07389      Fluide                   2294.0
# 10172          510.0           10.46945      Fluide                   2294.0
#
#                 Libelle noeud amont  Identifiant noeud aval  \
# 10168  Av_Champs_Elysees-Washington                  2293.0
# 10169  Av_Champs_Elysees-Washington                  2293.0
# 10170  Av_Champs_Elysees-Washington                  2293.0
# 10171  Av_Champs_Elysees-Washington                  2293.0
# 10172  Av_Champs_Elysees-Washington                  2293.0
#
#             Libelle noeud aval  ... lag_10_20 lag_10_21 lag_10_22 lag_10_23  \
# 10168  Av_Champs_Elysees-Berri  ...     667.0     904.0     941.0     960.0
# 10169  Av_Champs_Elysees-Berri  ...     525.0     667.0     904.0     941.0
# 10170  Av_Champs_Elysees-Berri  ...     639.0     525.0     667.0     904.0
# 10171  Av_Champs_Elysees-Berri  ...     564.0     639.0     525.0     667.0
# 10172  Av_Champs_Elysees-Berri  ...     642.0     564.0     639.0     525.0
#
#        cos_hour  cos_dayofweek  cos_month  sin_hour  sin_dayofweek  sin_month
# 10168  0.258819      -0.222521        0.5 -0.965926       0.974928  -0.866025
# 10169  0.500000      -0.222521        0.5 -0.866025       0.974928  -0.866025
# 10170  0.707107      -0.222521        0.5 -0.707107       0.974928  -0.866025
# 10171  0.866025      -0.222521        0.5 -0.500000       0.974928  -0.866025
# 10172  0.965926      -0.222521        0.5 -0.258819       0.974928  -0.866025
#
# [5 rows x 264 columns]

# %%
df_ml["date"] = df_ml["Date et heure de comptage"].dt.date
df_ml["is_sunday"] = (df_ml["Date et heure de comptage"].dt.dayofweek == 6).astype(int)
df_ml["month"] = df_ml["Date et heure de comptage"].dt.month
df_ml["year"] = df_ml["Date et heure de comptage"].dt.year

df_ml["error_abs"] = np.abs(model.predict(df_ml[features]) - df_ml["Débit horaire"])
df_ml["error"] = model.predict(df_ml[features]) - df_ml["Débit horaire"]
group = (
    df_ml[
        [
            "is_sunday",
            "date",
            "month",
            "year",
            "error",
            "error_abs",
            "Débit horaire",
        ]
    ]
    .groupby(["date"])
    .mean()
)

fig = go.Figure()
fig.add_trace(
    go.Box(
        x=0 * group["Débit horaire"],
        y=group["Débit horaire"],
        boxpoints="outliers",
        name="Débit horaire",
        marker_color="lightblue",
    )
)
fig.add_trace(
    go.Box(
        x=1 + 0 * group["Débit horaire"],
        y=group["error"],
        boxpoints="outliers",
        name="Erreur",
        marker_color="lightcoral",
    )
)
fig.update_layout(
    title="Diagramme en moustache du Débit horaire",
    yaxis_title="Débit horaire",
)
fig.show()

# %% [markdown]
# ## Paris respire

# %%
# plot Sundays with plotly
sundays = group[group["is_sunday"] == 1].sort_index()
fig = go.Figure()
fig.add_trace(
    go.Scatter(
        x=sundays.index,
        y=sundays["Débit horaire"],
        mode="lines+markers",
        name="Sunday - Débit horaire",
        hovertemplate="%{x}<br>Débit horaire: %{y}<extra></extra>",
    )
)
fig.update_layout(
    title="Débit horaire on Sundays",
    xaxis_title="Date",
    yaxis_title="Débit horaire",
    legend_title="Series",
)
fig.show()

# %%
df_sunday = group[group["is_sunday"] == 1]

# trouver l'index du min par mois/année
idx_min = df_sunday.groupby(["year", "month"])["Débit horaire"].idxmin()

# récupérer les lignes correspondantes
min_by_month_year = df_sunday.loc[idx_min].sort_values(["year", "month"])

min_by_month_year[["year", "month", "Débit horaire"]]
# min_by_month_year["Débit horaire"].to_csv("dataset/paris_respire.csv")
# Out:
#               year  month  Débit horaire
# date
# 2024-09-08  2024.0    9.0     407.458333
# 2024-10-06  2024.0   10.0     506.791667
# 2024-11-24  2024.0   11.0     197.000000
# 2024-12-01  2024.0   12.0     339.818182
# 2025-01-05  2025.0    1.0     655.166667
# 2025-02-02  2025.0    2.0     604.666667
# 2025-03-02  2025.0    3.0     504.250000
# 2025-04-13  2025.0    4.0     403.541667
# 2025-05-04  2025.0    5.0     500.565217
# 2025-06-01  2025.0    6.0     143.333333
# 2025-07-27  2025.0    7.0     293.909091
# 2025-08-17  2025.0    8.0     610.809524
# 2025-09-21  2025.0    9.0     292.434783
# 2025-10-05  2025.0   10.0     549.958333

# %%
fig = go.Figure()
fig.add_trace(
    go.Histogram(
        x=group["error_abs"],
        name="Erreur",
    )
)

# %%
group[["Débit horaire", "error"]][group["error_abs"] > 100]
# Out:
#             Débit horaire       error
# date
# 2024-09-02     322.416667  168.562355
# 2024-09-03     343.791667  108.163540
# 2024-09-08     407.458333  100.149586
# 2024-09-11     206.208333  170.501679
# 2024-09-12      62.666667  197.058897
# ...                   ...         ...
# 2025-10-24     839.000000  -28.738023
# 2025-10-25     802.000000  -50.499625
# 2025-10-26     692.391304  -16.163852
# 2025-10-27     683.625000   41.756710
# 2025-10-28     750.583333  -22.960239
#
# [75 rows x 2 columns]
